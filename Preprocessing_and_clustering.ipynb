# %%
# Libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from ydata_profiling import ProfileReport
import numpy as np

# %%
# Import data
df = pd.read_csv('./data/marketing_campaign_clean.csv', sep=',')

# %%
df
# Out:
#       Unnamed: 0  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0              0        1957  Graduation         Single  58138.0        0
# 1              1        1954  Graduation         Single  46344.0        1
# 2              2        1965  Graduation       Together  71613.0        0
# 3              3        1984  Graduation       Together  26646.0        1
# 4              4        1981         PhD        Married  58293.0        1
# ...          ...         ...         ...            ...      ...      ...
# 2049        2232        1986  Graduation         Single  26816.0        0
# 2050        2235        1967  Graduation        Married  61223.0        0
# 2051        2237        1981  Graduation       Divorced  56981.0        0
# 2052        2238        1956      Master       Together  69245.0        0
# 2053        2239        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  AcceptedCmp2  Complain  \
# ...
